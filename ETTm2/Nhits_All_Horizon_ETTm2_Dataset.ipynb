# %%
# !pip install NeuralForecast

# %%
import tensorflow as tf

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from neuralforecast.models import NHITS
from neuralforecast import NeuralForecast
from neuralforecast.core import NeuralForecast
from neuralforecast.models import Informer, Autoformer,NHITS
from neuralforecast.models import NBEATS,FEDformer
from neuralforecast.losses.numpy import mae,mse

# %%
X_df = pd.read_csv('/content/df_x.csv')
Y_df = pd.read_csv('/content/df_y.csv')

# %%
X_df
# Out:
#                         ds      ex_1      ex_2      ex_3      ex_4
# 0      2016-07-01 00:00:00 -0.500000  0.166667 -0.500000 -0.001370
# 1      2016-07-01 00:15:00 -0.500000  0.166667 -0.500000 -0.001370
# 2      2016-07-01 00:30:00 -0.500000  0.166667 -0.500000 -0.001370
# 3      2016-07-01 00:45:00 -0.500000  0.166667 -0.500000 -0.001370
# 4      2016-07-01 01:00:00 -0.456522  0.166667 -0.500000 -0.001370
# ...                    ...       ...       ...       ...       ...
# 57595  2018-02-20 22:45:00  0.456522 -0.333333  0.133333 -0.363014
# 57596  2018-02-20 23:00:00  0.500000 -0.333333  0.133333 -0.363014
# 57597  2018-02-20 23:15:00  0.500000 -0.333333  0.133333 -0.363014
# 57598  2018-02-20 23:30:00  0.500000 -0.333333  0.133333 -0.363014
# 57599  2018-02-20 23:45:00  0.500000 -0.333333  0.133333 -0.363014
#
# [57600 rows x 5 columns]

# %%
Y_df
# Out:
#                         ds unique_id         y
# 0      2016-07-01 00:00:00        OT  1.018032
# 1      2016-07-01 00:15:00        OT  0.980124
# 2      2016-07-01 00:30:00        OT  0.904223
# 3      2016-07-01 00:45:00        OT  0.885226
# 4      2016-07-01 01:00:00        OT  0.885226
# ...                    ...       ...       ...
# 57595  2018-02-20 22:45:00        OT -1.581325
# 57596  2018-02-20 23:00:00        OT -1.581325
# 57597  2018-02-20 23:15:00        OT -1.581325
# 57598  2018-02-20 23:30:00        OT -1.562328
# 57599  2018-02-20 23:45:00        OT -1.562328
#
# [57600 rows x 3 columns]

# %%
Y_df['unique_id'].unique()
# Out:
# array(['OT'], dtype=object)

# %%
Y_df['ex_1']=X_df['ex_1']
Y_df['ex_2']=X_df['ex_2']
Y_df['ex_3']=X_df['ex_3']
Y_df['ex_4']=X_df['ex_4']

Y_df=Y_df.dropna()

# %%
Y_df['ds'] = pd.to_datetime(Y_df['ds'])

# %% [markdown]
# ## Horizon 96

# %%
Y_df
# Out:
#                        ds unique_id         y      ex_1      ex_2      ex_3  \
# 0     2016-07-01 00:00:00        OT  1.018032 -0.500000  0.166667 -0.500000
# 1     2016-07-01 00:15:00        OT  0.980124 -0.500000  0.166667 -0.500000
# 2     2016-07-01 00:30:00        OT  0.904223 -0.500000  0.166667 -0.500000
# 3     2016-07-01 00:45:00        OT  0.885226 -0.500000  0.166667 -0.500000
# 4     2016-07-01 01:00:00        OT  0.885226 -0.456522  0.166667 -0.500000
# ...                   ...       ...       ...       ...       ...       ...
# 57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#            ex_4
# 0     -0.001370
# 1     -0.001370
# 2     -0.001370
# 3     -0.001370
# 4     -0.001370
# ...         ...
# 57595 -0.363014
# 57596 -0.363014
# 57597 -0.363014
# 57598 -0.363014
# 57599 -0.363014
#
# [57600 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:57504,:]
Y_test_df = Y_df.iloc[57504:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#     index                  ds unique_id         y      ex_1      ex_2  \
# 0   57504 2018-02-20 00:00:00        OT -1.277761 -0.500000 -0.333333
# 1   57505 2018-02-20 00:15:00        OT -1.277761 -0.500000 -0.333333
# 2   57506 2018-02-20 00:30:00        OT -1.277761 -0.500000 -0.333333
# 3   57507 2018-02-20 00:45:00        OT -1.277761 -0.500000 -0.333333
# 4   57508 2018-02-20 01:00:00        OT -1.277761 -0.456522 -0.333333
# ..    ...                 ...       ...       ...       ...       ...
# 91  57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333
# 92  57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333
# 93  57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333
# 94  57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333
# 95  57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333
#
#         ex_3      ex_4
# 0   0.133333 -0.363014
# 1   0.133333 -0.363014
# 2   0.133333 -0.363014
# 3   0.133333 -0.363014
# 4   0.133333 -0.363014
# ..       ...       ...
# 91  0.133333 -0.363014
# 92  0.133333 -0.363014
# 93  0.133333 -0.363014
# 94  0.133333 -0.363014
# 95  0.133333 -0.363014
#
# [96 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                     ds unique_id         y      ex_1      ex_2      ex_3  \
# 0  2018-02-20 00:00:00        OT -1.277761 -0.500000 -0.333333  0.133333
# 1  2018-02-20 00:15:00        OT -1.277761 -0.500000 -0.333333  0.133333
# 2  2018-02-20 00:30:00        OT -1.277761 -0.500000 -0.333333  0.133333
# 3  2018-02-20 00:45:00        OT -1.277761 -0.500000 -0.333333  0.133333
# 4  2018-02-20 01:00:00        OT -1.277761 -0.456522 -0.333333  0.133333
# ..                 ...       ...       ...       ...       ...       ...
# 91 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 92 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 93 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 94 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 95 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#         ex_4
# 0  -0.363014
# 1  -0.363014
# 2  -0.363014
# 3  -0.363014
# 4  -0.363014
# ..       ...
# 91 -0.363014
# 92 -0.363014
# 93 -0.363014
# 94 -0.363014
# 95 -0.363014
#
# [96 rows x 7 columns]

# %%
horizon = 96
model = NHITS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#            ds     NHITS
# unique_id
# OT          0 -1.276541
# OT          1 -1.273642
# OT          2 -1.275342
# OT          3 -1.272414
# OT          4 -1.269681
# ...        ..       ...
# OT         91 -1.214965
# OT         92 -1.213236
# OT         93 -1.213305
# OT         94 -1.220799
# OT         95 -1.215971
#
# [96 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NHITS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#        NHITS
# ds
# 0  -1.276541
# 1  -1.273642
# 2  -1.275342
# 3  -1.272414
# 4  -1.269681
# ..       ...
# 91 -1.214965
# 92 -1.213236
# 93 -1.213305
# 94 -1.220799
# 95 -1.215971
#
# [96 rows x 1 columns]

# %%
mae_nhits = mae(Y_test_df['y'], forecasts['NHITS'])
mse_nhits = mse(Y_test_df['y'], forecasts['NHITS'])
print(f'N-Beats MAE: {mae_nhits:.3f}')
print(f'N-Beats MSE: {mse_nhits:.3f}')
# Out:
# N-Beats MAE: 0.177
# N-Beats MSE: 0.049

# %% [markdown]
# ## Horizon 192

# %%
Y_df
# Out:
#                        ds unique_id         y      ex_1      ex_2      ex_3  \
# 0     2016-07-01 00:00:00        OT  1.018032 -0.500000  0.166667 -0.500000
# 1     2016-07-01 00:15:00        OT  0.980124 -0.500000  0.166667 -0.500000
# 2     2016-07-01 00:30:00        OT  0.904223 -0.500000  0.166667 -0.500000
# 3     2016-07-01 00:45:00        OT  0.885226 -0.500000  0.166667 -0.500000
# 4     2016-07-01 01:00:00        OT  0.885226 -0.456522  0.166667 -0.500000
# ...                   ...       ...       ...       ...       ...       ...
# 57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#            ex_4
# 0     -0.001370
# 1     -0.001370
# 2     -0.001370
# 3     -0.001370
# 4     -0.001370
# ...         ...
# 57595 -0.363014
# 57596 -0.363014
# 57597 -0.363014
# 57598 -0.363014
# 57599 -0.363014
#
# [57600 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:57408,:]
Y_test_df = Y_df.iloc[57408:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#      index                  ds unique_id         y      ex_1      ex_2  \
# 0    57408 2018-02-19 00:00:00        OT -1.429522 -0.500000 -0.500000
# 1    57409 2018-02-19 00:15:00        OT -1.429522 -0.500000 -0.500000
# 2    57410 2018-02-19 00:30:00        OT -1.429522 -0.500000 -0.500000
# 3    57411 2018-02-19 00:45:00        OT -1.429522 -0.500000 -0.500000
# 4    57412 2018-02-19 01:00:00        OT -1.429522 -0.456522 -0.500000
# ..     ...                 ...       ...       ...       ...       ...
# 187  57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333
# 188  57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333
# 189  57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333
# 190  57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333
# 191  57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333
#
#          ex_3      ex_4
# 0    0.100000 -0.365753
# 1    0.100000 -0.365753
# 2    0.100000 -0.365753
# 3    0.100000 -0.365753
# 4    0.100000 -0.365753
# ..        ...       ...
# 187  0.133333 -0.363014
# 188  0.133333 -0.363014
# 189  0.133333 -0.363014
# 190  0.133333 -0.363014
# 191  0.133333 -0.363014
#
# [192 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                      ds unique_id         y      ex_1      ex_2      ex_3  \
# 0   2018-02-19 00:00:00        OT -1.429522 -0.500000 -0.500000  0.100000
# 1   2018-02-19 00:15:00        OT -1.429522 -0.500000 -0.500000  0.100000
# 2   2018-02-19 00:30:00        OT -1.429522 -0.500000 -0.500000  0.100000
# 3   2018-02-19 00:45:00        OT -1.429522 -0.500000 -0.500000  0.100000
# 4   2018-02-19 01:00:00        OT -1.429522 -0.456522 -0.500000  0.100000
# ..                  ...       ...       ...       ...       ...       ...
# 187 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 188 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 189 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 190 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 191 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#          ex_4
# 0   -0.365753
# 1   -0.365753
# 2   -0.365753
# 3   -0.365753
# 4   -0.365753
# ..        ...
# 187 -0.363014
# 188 -0.363014
# 189 -0.363014
# 190 -0.363014
# 191 -0.363014
#
# [192 rows x 7 columns]

# %%
horizon = 192
model = NHITS(h=horizon, input_size=24,
               max_steps=2000,
               )
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#             ds     NHITS
# unique_id
# OT           0 -1.429645
# OT           1 -1.430591
# OT           2 -1.426778
# OT           3 -1.433004
# OT           4 -1.427784
# ...        ...       ...
# OT         187 -1.308540
# OT         188 -1.313950
# OT         189 -1.316398
# OT         190 -1.326345
# OT         191 -1.331750
#
# [192 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NHITS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#         NHITS
# ds
# 0   -1.429645
# 1   -1.430591
# 2   -1.426778
# 3   -1.433004
# 4   -1.427784
# ..        ...
# 187 -1.308540
# 188 -1.313950
# 189 -1.316398
# 190 -1.326345
# 191 -1.331750
#
# [192 rows x 1 columns]

# %%
mae_nhits = mae(Y_test_df['y'], forecasts['NHITS'])
mse_nhits = mse(Y_test_df['y'], forecasts['NHITS'])
print(f'Nhits MAE: {mae_nhits:.3f}')
print(f'Nhits MSE: {mse_nhits:.3f}')
# Out:
# Nhits MAE: 0.185
# Nhits MSE: 0.052

# %% [markdown]
# ## Horizon 336

# %%
Y_df
# Out:
#                        ds unique_id         y      ex_1      ex_2      ex_3  \
# 0     2016-07-01 00:00:00        OT  1.018032 -0.500000  0.166667 -0.500000
# 1     2016-07-01 00:15:00        OT  0.980124 -0.500000  0.166667 -0.500000
# 2     2016-07-01 00:30:00        OT  0.904223 -0.500000  0.166667 -0.500000
# 3     2016-07-01 00:45:00        OT  0.885226 -0.500000  0.166667 -0.500000
# 4     2016-07-01 01:00:00        OT  0.885226 -0.456522  0.166667 -0.500000
# ...                   ...       ...       ...       ...       ...       ...
# 57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#            ex_4
# 0     -0.001370
# 1     -0.001370
# 2     -0.001370
# 3     -0.001370
# 4     -0.001370
# ...         ...
# 57595 -0.363014
# 57596 -0.363014
# 57597 -0.363014
# 57598 -0.363014
# 57599 -0.363014
#
# [57600 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:57264,:]
Y_test_df = Y_df.iloc[57264:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#      index                  ds unique_id         y      ex_1      ex_2  \
# 0    57264 2018-02-17 12:00:00        OT -0.860344  0.021739  0.333333
# 1    57265 2018-02-17 12:15:00        OT -0.822393  0.021739  0.333333
# 2    57266 2018-02-17 12:30:00        OT -0.822393  0.021739  0.333333
# 3    57267 2018-02-17 12:45:00        OT -0.765445  0.021739  0.333333
# 4    57268 2018-02-17 13:00:00        OT -0.708540  0.065217  0.333333
# ..     ...                 ...       ...       ...       ...       ...
# 331  57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333
# 332  57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333
# 333  57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333
# 334  57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333
# 335  57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333
#
#          ex_3      ex_4
# 0    0.033333 -0.371233
# 1    0.033333 -0.371233
# 2    0.033333 -0.371233
# 3    0.033333 -0.371233
# 4    0.033333 -0.371233
# ..        ...       ...
# 331  0.133333 -0.363014
# 332  0.133333 -0.363014
# 333  0.133333 -0.363014
# 334  0.133333 -0.363014
# 335  0.133333 -0.363014
#
# [336 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                      ds unique_id         y      ex_1      ex_2      ex_3  \
# 0   2018-02-17 12:00:00        OT -0.860344  0.021739  0.333333  0.033333
# 1   2018-02-17 12:15:00        OT -0.822393  0.021739  0.333333  0.033333
# 2   2018-02-17 12:30:00        OT -0.822393  0.021739  0.333333  0.033333
# 3   2018-02-17 12:45:00        OT -0.765445  0.021739  0.333333  0.033333
# 4   2018-02-17 13:00:00        OT -0.708540  0.065217  0.333333  0.033333
# ..                  ...       ...       ...       ...       ...       ...
# 331 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 332 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 333 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 334 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 335 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#          ex_4
# 0   -0.371233
# 1   -0.371233
# 2   -0.371233
# 3   -0.371233
# 4   -0.371233
# ..        ...
# 331 -0.363014
# 332 -0.363014
# 333 -0.363014
# 334 -0.363014
# 335 -0.363014
#
# [336 rows x 7 columns]

# %%
horizon = 336
model = NHITS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#             ds     NHITS
# unique_id
# OT           0 -0.856910
# OT           1 -0.820124
# OT           2 -0.780833
# OT           3 -0.755506
# OT           4 -0.722648
# ...        ...       ...
# OT         331 -1.183239
# OT         332 -1.192368
# OT         333 -1.202296
# OT         334 -1.223330
# OT         335 -1.225550
#
# [336 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NHITS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#         NHITS
# ds
# 0   -0.856910
# 1   -0.820124
# 2   -0.780833
# 3   -0.755506
# 4   -0.722648
# ..        ...
# 331 -1.183239
# 332 -1.192368
# 333 -1.202296
# 334 -1.223330
# 335 -1.225550
#
# [336 rows x 1 columns]

# %%
mae_nhits = mae(Y_test_df['y'], forecasts['NHITS'])
mse_nhits = mse(Y_test_df['y'], forecasts['NHITS'])
print(f'Nhits MAE: {mae_nhits:.3f}')
print(f'Nhits MSE: {mse_nhits:.3f}')
# Out:
# Nhits MAE: 0.274
# Nhits MSE: 0.130

# %% [markdown]
# ## Horizon 720

# %%
Y_df
# Out:
#                        ds unique_id         y      ex_1      ex_2      ex_3  \
# 0     2016-07-01 00:00:00        OT  1.018032 -0.500000  0.166667 -0.500000
# 1     2016-07-01 00:15:00        OT  0.980124 -0.500000  0.166667 -0.500000
# 2     2016-07-01 00:30:00        OT  0.904223 -0.500000  0.166667 -0.500000
# 3     2016-07-01 00:45:00        OT  0.885226 -0.500000  0.166667 -0.500000
# 4     2016-07-01 01:00:00        OT  0.885226 -0.456522  0.166667 -0.500000
# ...                   ...       ...       ...       ...       ...       ...
# 57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#            ex_4
# 0     -0.001370
# 1     -0.001370
# 2     -0.001370
# 3     -0.001370
# 4     -0.001370
# ...         ...
# 57595 -0.363014
# 57596 -0.363014
# 57597 -0.363014
# 57598 -0.363014
# 57599 -0.363014
#
# [57600 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:56880,:]
Y_test_df = Y_df.iloc[56880:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#      index                  ds unique_id         y      ex_1      ex_2  \
# 0    56880 2018-02-13 12:00:00        OT -0.689543  0.021739 -0.333333
# 1    56881 2018-02-13 12:15:00        OT -0.632682  0.021739 -0.333333
# 2    56882 2018-02-13 12:30:00        OT -0.613685  0.021739 -0.333333
# 3    56883 2018-02-13 12:45:00        OT -0.575734  0.021739 -0.333333
# 4    56884 2018-02-13 13:00:00        OT -0.518786  0.065217 -0.333333
# ..     ...                 ...       ...       ...       ...       ...
# 715  57595 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333
# 716  57596 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333
# 717  57597 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333
# 718  57598 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333
# 719  57599 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333
#
#          ex_3      ex_4
# 0   -0.100000 -0.382192
# 1   -0.100000 -0.382192
# 2   -0.100000 -0.382192
# 3   -0.100000 -0.382192
# 4   -0.100000 -0.382192
# ..        ...       ...
# 715  0.133333 -0.363014
# 716  0.133333 -0.363014
# 717  0.133333 -0.363014
# 718  0.133333 -0.363014
# 719  0.133333 -0.363014
#
# [720 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                      ds unique_id         y      ex_1      ex_2      ex_3  \
# 0   2018-02-13 12:00:00        OT -0.689543  0.021739 -0.333333 -0.100000
# 1   2018-02-13 12:15:00        OT -0.632682  0.021739 -0.333333 -0.100000
# 2   2018-02-13 12:30:00        OT -0.613685  0.021739 -0.333333 -0.100000
# 3   2018-02-13 12:45:00        OT -0.575734  0.021739 -0.333333 -0.100000
# 4   2018-02-13 13:00:00        OT -0.518786  0.065217 -0.333333 -0.100000
# ..                  ...       ...       ...       ...       ...       ...
# 715 2018-02-20 22:45:00        OT -1.581325  0.456522 -0.333333  0.133333
# 716 2018-02-20 23:00:00        OT -1.581325  0.500000 -0.333333  0.133333
# 717 2018-02-20 23:15:00        OT -1.581325  0.500000 -0.333333  0.133333
# 718 2018-02-20 23:30:00        OT -1.562328  0.500000 -0.333333  0.133333
# 719 2018-02-20 23:45:00        OT -1.562328  0.500000 -0.333333  0.133333
#
#          ex_4
# 0   -0.382192
# 1   -0.382192
# 2   -0.382192
# 3   -0.382192
# 4   -0.382192
# ..        ...
# 715 -0.363014
# 716 -0.363014
# 717 -0.363014
# 718 -0.363014
# 719 -0.363014
#
# [720 rows x 7 columns]

# %%
horizon = 720
model = NHITS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#             ds     NHITS
# unique_id
# OT           0 -0.679337
# OT           1 -0.590275
# OT           2 -0.537911
# OT           3 -0.520199
# OT           4 -0.457572
# ...        ...       ...
# OT         715 -1.026803
# OT         716 -1.051655
# OT         717 -1.055806
# OT         718 -1.010208
# OT         719 -1.012019
#
# [720 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NHITS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#         NHITS
# ds
# 0   -0.679337
# 1   -0.590275
# 2   -0.537911
# 3   -0.520199
# 4   -0.457572
# ..        ...
# 715 -1.026803
# 716 -1.051655
# 717 -1.055806
# 718 -1.010208
# 719 -1.012019
#
# [720 rows x 1 columns]

# %%
mae_nhits = mae(Y_test_df['y'], forecasts['NHITS'])
mse_nhits = mse(Y_test_df['y'], forecasts['NHITS'])
print(f'Nhits MAE: {mae_nhits:.3f}')
print(f'Nhits MSE: {mse_nhits:.3f}')
# Out:
# Nhits MAE: 0.364
# Nhits MSE: 0.197
