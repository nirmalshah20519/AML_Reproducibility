# %%
# %%capture
pip install NeuralForecast

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from neuralforecast.models import NHITS
from neuralforecast import NeuralForecast
from neuralforecast.core import NeuralForecast
from neuralforecast.models import Informer, Autoformer,NHITS
from neuralforecast.models import NBEATS,FEDformer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# X_df = pd.read_csv('/content/drive/MyDrive/AML/traffic/M/df_x.csv')
X_df = pd.read_csv('/content/drive/MyDrive/traffic/M/df_x.csv')
# Y_df = pd.read_csv('/content/drive/MyDrive/AML/traffic/M/df_y.csv')
Y_df = pd.read_csv('/content/drive/MyDrive/traffic/M/df_y.csv')

# %%
X_df
# Out:
#                         ds      ex_1      ex_2      ex_3     ex_4
# 0      2016-07-01 02:00:00 -0.413043  0.166667 -0.500000 -0.00137
# 1      2016-07-01 03:00:00 -0.369565  0.166667 -0.500000 -0.00137
# 2      2016-07-01 04:00:00 -0.326087  0.166667 -0.500000 -0.00137
# 3      2016-07-01 05:00:00 -0.282609  0.166667 -0.500000 -0.00137
# 4      2016-07-01 06:00:00 -0.239130  0.166667 -0.500000 -0.00137
# ...                    ...       ...       ...       ...      ...
# 17539  2018-07-01 21:00:00  0.413043  0.500000 -0.500000 -0.00411
# 17540  2018-07-01 22:00:00  0.456522  0.500000 -0.500000 -0.00411
# 17541  2018-07-01 23:00:00  0.500000  0.500000 -0.500000 -0.00411
# 17542  2018-07-02 00:00:00 -0.500000 -0.500000 -0.466667 -0.00137
# 17543  2018-07-02 01:00:00 -0.456522 -0.500000 -0.466667 -0.00137
#
# [17544 rows x 5 columns]

# %%
a=Y_df['unique_id'].unique()
a.size
# Out:
# 862

# %%
merged_df = pd.merge(Y_df, X_df[['ds', 'ex_1', 'ex_2','ex_3','ex_4']], on='ds', how='left')
merged_df
# Out:
#                            ds unique_id         y      ex_1      ex_2  \
# 0         2016-07-01 02:00:00         0 -0.711224 -0.413043  0.166667
# 1         2016-07-01 02:00:00         1 -0.643331 -0.413043  0.166667
# 2         2016-07-01 02:00:00         2 -0.925668 -0.413043  0.166667
# 3         2016-07-01 02:00:00         3 -1.182531 -0.413043  0.166667
# 4         2016-07-01 02:00:00         4 -0.569992 -0.413043  0.166667
# ...                       ...       ...       ...       ...       ...
# 15122923  2018-07-02 01:00:00       857 -0.311380 -0.456522 -0.500000
# 15122924  2018-07-02 01:00:00       858 -2.129480 -0.456522 -0.500000
# 15122925  2018-07-02 01:00:00       859 -1.582374 -0.456522 -0.500000
# 15122926  2018-07-02 01:00:00       860 -0.555770 -0.456522 -0.500000
# 15122927  2018-07-02 01:00:00        OT -0.495391 -0.456522 -0.500000
#
#               ex_3     ex_4
# 0        -0.500000 -0.00137
# 1        -0.500000 -0.00137
# 2        -0.500000 -0.00137
# 3        -0.500000 -0.00137
# 4        -0.500000 -0.00137
# ...            ...      ...
# 15122923 -0.466667 -0.00137
# 15122924 -0.466667 -0.00137
# 15122925 -0.466667 -0.00137
# 15122926 -0.466667 -0.00137
# 15122927 -0.466667 -0.00137
#
# [15122928 rows x 7 columns]

# %%
filtered_df = merged_df[merged_df['unique_id'] == 'OT']
filtered_df.reset_index(drop=True, inplace=True)
# filtered_df.drop("ds",axis=1,inplace=True)
filtered_df['ds'] = pd.to_datetime(filtered_df['ds'])

Y_df=filtered_df
Y_df
# Out:
# <ipython-input-8-9b593517d244>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['ds'] = pd.to_datetime(filtered_df['ds'])
#                        ds unique_id         y      ex_1      ex_2      ex_3  \
# 0     2016-07-01 02:00:00        OT -0.991924 -0.413043  0.166667 -0.500000
# 1     2016-07-01 03:00:00        OT -0.906315 -0.369565  0.166667 -0.500000
# 2     2016-07-01 04:00:00        OT -1.071826 -0.326087  0.166667 -0.500000
# 3     2016-07-01 05:00:00        OT -1.277288 -0.282609  0.166667 -0.500000
# 4     2016-07-01 06:00:00        OT -1.459921 -0.239130  0.166667 -0.500000
# ...                   ...       ...       ...       ...       ...       ...
# 17539 2018-07-01 21:00:00        OT  0.765917  0.413043  0.500000 -0.500000
# 17540 2018-07-01 22:00:00        OT  0.389237  0.456522  0.500000 -0.500000
# 17541 2018-07-01 23:00:00        OT  0.172360  0.500000  0.500000 -0.500000
# 17542 2018-07-02 00:00:00        OT -0.090175 -0.500000 -0.500000 -0.466667
# 17543 2018-07-02 01:00:00        OT -0.495391 -0.456522 -0.500000 -0.466667
#
#           ex_4
# 0     -0.00137
# 1     -0.00137
# 2     -0.00137
# 3     -0.00137
# 4     -0.00137
# ...        ...
# 17539 -0.00411
# 17540 -0.00411
# 17541 -0.00411
# 17542 -0.00137
# 17543 -0.00137
#
# [17544 rows x 7 columns]

# %%
Y_df['unique_id'].unique()
# Out:
# array(['OT'], dtype=object)

# %%
Y_df.shape
# Out:
# (17544, 7)

# %% [markdown]
# ## NBeats Horizon 96

# %%
Y_df
# Out:
#                        ds unique_id         y      ex_1      ex_2      ex_3  \
# 0     2016-07-01 02:00:00        OT -0.991924 -0.413043  0.166667 -0.500000
# 1     2016-07-01 03:00:00        OT -0.906315 -0.369565  0.166667 -0.500000
# 2     2016-07-01 04:00:00        OT -1.071826 -0.326087  0.166667 -0.500000
# 3     2016-07-01 05:00:00        OT -1.277288 -0.282609  0.166667 -0.500000
# 4     2016-07-01 06:00:00        OT -1.459921 -0.239130  0.166667 -0.500000
# ...                   ...       ...       ...       ...       ...       ...
# 17539 2018-07-01 21:00:00        OT  0.765917  0.413043  0.500000 -0.500000
# 17540 2018-07-01 22:00:00        OT  0.389237  0.456522  0.500000 -0.500000
# 17541 2018-07-01 23:00:00        OT  0.172360  0.500000  0.500000 -0.500000
# 17542 2018-07-02 00:00:00        OT -0.090175 -0.500000 -0.500000 -0.466667
# 17543 2018-07-02 01:00:00        OT -0.495391 -0.456522 -0.500000 -0.466667
#
#           ex_4
# 0     -0.00137
# 1     -0.00137
# 2     -0.00137
# 3     -0.00137
# 4     -0.00137
# ...        ...
# 17539 -0.00411
# 17540 -0.00411
# 17541 -0.00411
# 17542 -0.00137
# 17543 -0.00137
#
# [17544 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:17448,:]
Y_test_df = Y_df.iloc[17448:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#     index                  ds unique_id         y      ex_1  ex_2      ex_3  \
# 0   17448 2018-06-28 02:00:00        OT -1.168850 -0.413043   0.0  0.400000
# 1   17449 2018-06-28 03:00:00        OT -1.380019 -0.369565   0.0  0.400000
# 2   17450 2018-06-28 04:00:00        OT -1.414263 -0.326087   0.0  0.400000
# 3   17451 2018-06-28 05:00:00        OT -1.380019 -0.282609   0.0  0.400000
# 4   17452 2018-06-28 06:00:00        OT -1.168850 -0.239130   0.0  0.400000
# ..    ...                 ...       ...       ...       ...   ...       ...
# 91  17539 2018-07-01 21:00:00        OT  0.765917  0.413043   0.5 -0.500000
# 92  17540 2018-07-01 22:00:00        OT  0.389237  0.456522   0.5 -0.500000
# 93  17541 2018-07-01 23:00:00        OT  0.172360  0.500000   0.5 -0.500000
# 94  17542 2018-07-02 00:00:00        OT -0.090175 -0.500000  -0.5 -0.466667
# 95  17543 2018-07-02 01:00:00        OT -0.495391 -0.456522  -0.5 -0.466667
#
#         ex_4
# 0  -0.012329
# 1  -0.012329
# 2  -0.012329
# 3  -0.012329
# 4  -0.012329
# ..       ...
# 91 -0.004110
# 92 -0.004110
# 93 -0.004110
# 94 -0.001370
# 95 -0.001370
#
# [96 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                     ds unique_id         y      ex_1  ex_2      ex_3      ex_4
# 0  2018-06-28 02:00:00        OT -1.168850 -0.413043   0.0  0.400000 -0.012329
# 1  2018-06-28 03:00:00        OT -1.380019 -0.369565   0.0  0.400000 -0.012329
# 2  2018-06-28 04:00:00        OT -1.414263 -0.326087   0.0  0.400000 -0.012329
# 3  2018-06-28 05:00:00        OT -1.380019 -0.282609   0.0  0.400000 -0.012329
# 4  2018-06-28 06:00:00        OT -1.168850 -0.239130   0.0  0.400000 -0.012329
# ..                 ...       ...       ...       ...   ...       ...       ...
# 91 2018-07-01 21:00:00        OT  0.765917  0.413043   0.5 -0.500000 -0.004110
# 92 2018-07-01 22:00:00        OT  0.389237  0.456522   0.5 -0.500000 -0.004110
# 93 2018-07-01 23:00:00        OT  0.172360  0.500000   0.5 -0.500000 -0.004110
# 94 2018-07-02 00:00:00        OT -0.090175 -0.500000  -0.5 -0.466667 -0.001370
# 95 2018-07-02 01:00:00        OT -0.495391 -0.456522  -0.5 -0.466667 -0.001370
#
# [96 rows x 7 columns]

# %%
horizon = 96
model = NBEATS(h=horizon, input_size=10,
               max_steps=10,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# /usr/local/lib/python3.10/dist-packages/neuralforecast/common/_base_model.py:204: UserWarning: val_check_steps is greater than max_steps,                     setting val_check_steps to max_steps
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 2.7 M
# -----------------------------------------------
# 2.6 M     Trainable params
# 20.5 K    Non-trainable params
# 2.7 M     Total params
# 10.615    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=10` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#            ds    NBEATS
# unique_id
# OT          0 -1.765630
# OT          1 -1.740445
# OT          2 -1.698432
# OT          3 -1.961919
# OT          4 -1.706607
# ...        ..       ...
# OT         91  0.915367
# OT         92  0.640388
# OT         93  0.212992
# OT         94 -0.671353
# OT         95 -1.411980
#
# [96 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#       NBEATS
# ds
# 0  -1.765630
# 1  -1.740445
# 2  -1.698432
# 3  -1.961919
# 4  -1.706607
# ..       ...
# 91  0.915367
# 92  0.640388
# 93  0.212992
# 94 -0.671353
# 95 -1.411980
#
# [96 rows x 1 columns]

# %%
from neuralforecast.losses.numpy import mae,mse


mae_nBeats = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_nBeats = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'nBeats MAE: {mae_nBeats:.3f}')
print(f'nBeats MSE: {mse_nBeats:.3f}')
# Out:
# nBeats MAE: 0.346
# nBeats MSE: 0.174

# %% [markdown]
# ## NBeats Horizon 192

# %%
Y_train_df = Y_df.iloc[:17352,:]
Y_test_df = Y_df.iloc[17352:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#      index                  ds unique_id         y      ex_1  ex_2      ex_3  \
# 0    17352 2018-06-24 02:00:00        OT -0.837828 -0.413043   0.5  0.266667
# 1    17353 2018-06-24 03:00:00        OT -1.168850 -0.369565   0.5  0.266667
# 2    17354 2018-06-24 04:00:00        OT -1.340068 -0.326087   0.5  0.266667
# 3    17355 2018-06-24 05:00:00        OT -1.374312 -0.282609   0.5  0.266667
# 4    17356 2018-06-24 06:00:00        OT -1.340068 -0.239130   0.5  0.266667
# ..     ...                 ...       ...       ...       ...   ...       ...
# 187  17539 2018-07-01 21:00:00        OT  0.765917  0.413043   0.5 -0.500000
# 188  17540 2018-07-01 22:00:00        OT  0.389237  0.456522   0.5 -0.500000
# 189  17541 2018-07-01 23:00:00        OT  0.172360  0.500000   0.5 -0.500000
# 190  17542 2018-07-02 00:00:00        OT -0.090175 -0.500000  -0.5 -0.466667
# 191  17543 2018-07-02 01:00:00        OT -0.495391 -0.456522  -0.5 -0.466667
#
#          ex_4
# 0   -0.023288
# 1   -0.023288
# 2   -0.023288
# 3   -0.023288
# 4   -0.023288
# ..        ...
# 187 -0.004110
# 188 -0.004110
# 189 -0.004110
# 190 -0.001370
# 191 -0.001370
#
# [192 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                      ds unique_id         y      ex_1  ex_2      ex_3  \
# 0   2018-06-24 02:00:00        OT -0.837828 -0.413043   0.5  0.266667
# 1   2018-06-24 03:00:00        OT -1.168850 -0.369565   0.5  0.266667
# 2   2018-06-24 04:00:00        OT -1.340068 -0.326087   0.5  0.266667
# 3   2018-06-24 05:00:00        OT -1.374312 -0.282609   0.5  0.266667
# 4   2018-06-24 06:00:00        OT -1.340068 -0.239130   0.5  0.266667
# ..                  ...       ...       ...       ...   ...       ...
# 187 2018-07-01 21:00:00        OT  0.765917  0.413043   0.5 -0.500000
# 188 2018-07-01 22:00:00        OT  0.389237  0.456522   0.5 -0.500000
# 189 2018-07-01 23:00:00        OT  0.172360  0.500000   0.5 -0.500000
# 190 2018-07-02 00:00:00        OT -0.090175 -0.500000  -0.5 -0.466667
# 191 2018-07-02 01:00:00        OT -0.495391 -0.456522  -0.5 -0.466667
#
#          ex_4
# 0   -0.023288
# 1   -0.023288
# 2   -0.023288
# 3   -0.023288
# 4   -0.023288
# ..        ...
# 187 -0.004110
# 188 -0.004110
# 189 -0.004110
# 190 -0.001370
# 191 -0.001370
#
# [192 rows x 7 columns]

# %%
horizon = 192
model = NBEATS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 3.0 M
# -----------------------------------------------
# 2.9 M     Trainable params
# 83.2 K    Non-trainable params
# 3.0 M     Total params
# 11.965    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#             ds    NBEATS
# unique_id
# OT           0 -0.869197
# OT           1 -1.180596
# OT           2 -1.282011
# OT           3 -1.415716
# OT           4 -1.556206
# ...        ...       ...
# OT         187  0.804161
# OT         188  0.199822
# OT         189  0.081212
# OT         190 -0.188565
# OT         191 -0.542492
#
# [192 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#        NBEATS
# ds
# 0   -0.869197
# 1   -1.180596
# 2   -1.282011
# 3   -1.415716
# 4   -1.556206
# ..        ...
# 187  0.804161
# 188  0.199822
# 189  0.081212
# 190 -0.188565
# 191 -0.542492
#
# [192 rows x 1 columns]

# %%
from neuralforecast.losses.numpy import mae,mse


mae_nBeats = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_nBeats = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'mae_nBeats MAE: {mae_nBeats:.3f}')
print(f'mse_nBeats MSE: {mse_nBeats:.3f}')
# Out:
# mae_nBeats MAE: 0.351
# mse_nBeats MSE: 0.229

# %% [markdown]
# ## NBeatsx Horizon = 336

# %%
Y_train_df = Y_df.iloc[:17208,:]
Y_test_df = Y_df.iloc[17208:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#      index                  ds unique_id         y      ex_1  ex_2      ex_3  \
# 0    17208 2018-06-18 02:00:00        OT -0.729390 -0.413043  -0.5  0.066667
# 1    17209 2018-06-18 03:00:00        OT -1.117484 -0.369565  -0.5  0.066667
# 2    17210 2018-06-18 04:00:00        OT -1.277288 -0.326087  -0.5  0.066667
# 3    17211 2018-06-18 05:00:00        OT -1.402848 -0.282609  -0.5  0.066667
# 4    17212 2018-06-18 06:00:00        OT -1.465628 -0.239130  -0.5  0.066667
# ..     ...                 ...       ...       ...       ...   ...       ...
# 331  17539 2018-07-01 21:00:00        OT  0.765917  0.413043   0.5 -0.500000
# 332  17540 2018-07-01 22:00:00        OT  0.389237  0.456522   0.5 -0.500000
# 333  17541 2018-07-01 23:00:00        OT  0.172360  0.500000   0.5 -0.500000
# 334  17542 2018-07-02 00:00:00        OT -0.090175 -0.500000  -0.5 -0.466667
# 335  17543 2018-07-02 01:00:00        OT -0.495391 -0.456522  -0.5 -0.466667
#
#          ex_4
# 0   -0.039726
# 1   -0.039726
# 2   -0.039726
# 3   -0.039726
# 4   -0.039726
# ..        ...
# 331 -0.004110
# 332 -0.004110
# 333 -0.004110
# 334 -0.001370
# 335 -0.001370
#
# [336 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                      ds unique_id         y      ex_1  ex_2      ex_3  \
# 0   2018-06-18 02:00:00        OT -0.729390 -0.413043  -0.5  0.066667
# 1   2018-06-18 03:00:00        OT -1.117484 -0.369565  -0.5  0.066667
# 2   2018-06-18 04:00:00        OT -1.277288 -0.326087  -0.5  0.066667
# 3   2018-06-18 05:00:00        OT -1.402848 -0.282609  -0.5  0.066667
# 4   2018-06-18 06:00:00        OT -1.465628 -0.239130  -0.5  0.066667
# ..                  ...       ...       ...       ...   ...       ...
# 331 2018-07-01 21:00:00        OT  0.765917  0.413043   0.5 -0.500000
# 332 2018-07-01 22:00:00        OT  0.389237  0.456522   0.5 -0.500000
# 333 2018-07-01 23:00:00        OT  0.172360  0.500000   0.5 -0.500000
# 334 2018-07-02 00:00:00        OT -0.090175 -0.500000  -0.5 -0.466667
# 335 2018-07-02 01:00:00        OT -0.495391 -0.456522  -0.5 -0.466667
#
#          ex_4
# 0   -0.039726
# 1   -0.039726
# 2   -0.039726
# 3   -0.039726
# 4   -0.039726
# ..        ...
# 331 -0.004110
# 332 -0.004110
# 333 -0.004110
# 334 -0.001370
# 335 -0.001370
#
# [336 rows x 7 columns]

# %%
horizon = 336
model = NBEATS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 3.5 M
# -----------------------------------------------
# 3.3 M     Trainable params
# 242 K     Non-trainable params
# 3.5 M     Total params
# 14.079    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#             ds    NBEATS
# unique_id
# OT           0 -0.618103
# OT           1 -1.049381
# OT           2 -1.288679
# OT           3 -1.366805
# OT           4 -1.485769
# ...        ...       ...
# OT         331  1.562187
# OT         332  0.954576
# OT         333  0.453689
# OT         334  0.093776
# OT         335 -0.328957
#
# [336 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#        NBEATS
# ds
# 0   -0.618103
# 1   -1.049381
# 2   -1.288679
# 3   -1.366805
# 4   -1.485769
# ..        ...
# 331  1.562187
# 332  0.954576
# 333  0.453689
# 334  0.093776
# 335 -0.328957
#
# [336 rows x 1 columns]

# %%
from neuralforecast.losses.numpy import mae,mse


mae_nBeats = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_nBeats = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'NBeats MAE: {mae_nBeats:.3f}')
print(f'NBeats MSE: {mse_nBeats:.3f}')
# Out:
# NBeats MAE: 0.350
# NBeats MSE: 0.306

# %% [markdown]
# ## NBeatsx Horizon = 720

# %%
Y_train_df = Y_df.iloc[:16824,:]
Y_test_df = Y_df.iloc[16824:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#      index                  ds unique_id         y      ex_1      ex_2  \
# 0    16824 2018-06-02 02:00:00        OT -1.088948 -0.413043  0.333333
# 1    16825 2018-06-02 03:00:00        OT -1.374312 -0.369565  0.333333
# 2    16826 2018-06-02 04:00:00        OT -1.419970 -0.326087  0.333333
# 3    16827 2018-06-02 05:00:00        OT -1.317239 -0.282609  0.333333
# 4    16828 2018-06-02 06:00:00        OT -1.140314 -0.239130  0.333333
# ..     ...                 ...       ...       ...       ...       ...
# 715  17539 2018-07-01 21:00:00        OT  0.765917  0.413043  0.500000
# 716  17540 2018-07-01 22:00:00        OT  0.389237  0.456522  0.500000
# 717  17541 2018-07-01 23:00:00        OT  0.172360  0.500000  0.500000
# 718  17542 2018-07-02 00:00:00        OT -0.090175 -0.500000 -0.500000
# 719  17543 2018-07-02 01:00:00        OT -0.495391 -0.456522 -0.500000
#
#          ex_3      ex_4
# 0   -0.466667 -0.083562
# 1   -0.466667 -0.083562
# 2   -0.466667 -0.083562
# 3   -0.466667 -0.083562
# 4   -0.466667 -0.083562
# ..        ...       ...
# 715 -0.500000 -0.004110
# 716 -0.500000 -0.004110
# 717 -0.500000 -0.004110
# 718 -0.466667 -0.001370
# 719 -0.466667 -0.001370
#
# [720 rows x 8 columns]

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#                      ds unique_id         y      ex_1      ex_2      ex_3  \
# 0   2018-06-02 02:00:00        OT -1.088948 -0.413043  0.333333 -0.466667
# 1   2018-06-02 03:00:00        OT -1.374312 -0.369565  0.333333 -0.466667
# 2   2018-06-02 04:00:00        OT -1.419970 -0.326087  0.333333 -0.466667
# 3   2018-06-02 05:00:00        OT -1.317239 -0.282609  0.333333 -0.466667
# 4   2018-06-02 06:00:00        OT -1.140314 -0.239130  0.333333 -0.466667
# ..                  ...       ...       ...       ...       ...       ...
# 715 2018-07-01 21:00:00        OT  0.765917  0.413043  0.500000 -0.500000
# 716 2018-07-01 22:00:00        OT  0.389237  0.456522  0.500000 -0.500000
# 717 2018-07-01 23:00:00        OT  0.172360  0.500000  0.500000 -0.500000
# 718 2018-07-02 00:00:00        OT -0.090175 -0.500000 -0.500000 -0.466667
# 719 2018-07-02 01:00:00        OT -0.495391 -0.456522 -0.500000 -0.466667
#
#          ex_4
# 0   -0.083562
# 1   -0.083562
# 2   -0.083562
# 3   -0.083562
# 4   -0.083562
# ..        ...
# 715 -0.004110
# 716 -0.004110
# 717 -0.004110
# 718 -0.001370
# 719 -0.001370
#
# [720 rows x 7 columns]

# %%
horizon = 720
model = NBEATS(h=horizon, input_size=24,
               max_steps=500,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq='H')

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 5.3 M
# -----------------------------------------------
# 4.3 M     Trainable params
# 1.1 M     Non-trainable params
# 5.3 M     Total params
# 21.338    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=500` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#             ds    NBEATS
# unique_id
# OT           0 -1.102144
# OT           1 -1.321246
# OT           2 -1.363912
# OT           3 -1.417808
# OT           4 -1.124968
# ...        ...       ...
# OT         715  1.124884
# OT         716  0.539315
# OT         717  0.170691
# OT         718 -0.210436
# OT         719 -0.735399
#
# [720 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#        NBEATS
# ds
# 0   -1.102144
# 1   -1.321246
# 2   -1.363912
# 3   -1.417808
# 4   -1.124968
# ..        ...
# 715  1.124884
# 716  0.539315
# 717  0.170691
# 718 -0.210436
# 719 -0.735399
#
# [720 rows x 1 columns]

# %%
from neuralforecast.losses.numpy import mae,mse


mae_autoformer = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_autoformer = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'Autoformer MAE: {mae_autoformer:.3f}')
print(f'Autoformer MSE: {mse_autoformer:.3f}')
# Out:
# Autoformer MAE: 0.264
# Autoformer MSE: 0.186
