# %%
pip install NeuralForecast
# Out:
# Requirement already satisfied: NeuralForecast in /usr/local/lib/python3.10/dist-packages (1.7.1)
# Requirement already satisfied: coreforecast>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (0.0.8)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (2023.6.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (1.25.2)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (2.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (2.2.1+cu121)
# Requirement already satisfied: pytorch-lightning>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (2.2.2)
# Requirement already satisfied: ray[tune]>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (2.11.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (3.6.1)
# Requirement already satisfied: utilsforecast>=0.0.25 in /usr/local/lib/python3.10/dist-packages (from NeuralForecast) (0.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->NeuralForecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->NeuralForecast) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->NeuralForecast) (2024.1)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->NeuralForecast) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->NeuralForecast) (6.0.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->NeuralForecast) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->NeuralForecast) (24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->NeuralForecast) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->NeuralForecast) (0.11.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (3.13.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (1.0.8)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (3.20.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (2.31.0)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->NeuralForecast) (14.0.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->NeuralForecast) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->NeuralForecast) (12.4.127)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna->NeuralForecast) (1.13.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna->NeuralForecast) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna->NeuralForecast) (2.0.29)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->NeuralForecast) (1.3.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec->NeuralForecast) (3.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning>=2.0.0->NeuralForecast) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->NeuralForecast) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna->NeuralForecast) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->NeuralForecast) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]>=2.2.0->NeuralForecast) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]>=2.2.0->NeuralForecast) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]>=2.2.0->NeuralForecast) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]>=2.2.0->NeuralForecast) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->NeuralForecast) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->NeuralForecast) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->NeuralForecast) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->NeuralForecast) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->NeuralForecast) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->NeuralForecast) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->NeuralForecast) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->NeuralForecast) (4.0.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from neuralforecast.models import NHITS
from neuralforecast import NeuralForecast
from neuralforecast.core import NeuralForecast
from neuralforecast.models import Informer, Autoformer,NHITS
from neuralforecast.models import NBEATS,FEDformer
from neuralforecast.losses.numpy import mae,mse

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# X_df = pd.read_csv('/content/df_x.csv')
# Y_df = pd.read_csv('/content/df_y.csv')

X_df = pd.read_csv('/content/drive/MyDrive/AML Reproducibility Challenge/datasets/ili/M/df_x.csv')
Y_df = pd.read_csv('/content/drive/MyDrive/AML Reproducibility Challenge/datasets/ili/M/df_y.csv')

# X_df = pd.read_csv('@datasets_reproducibity/Exchange/S/df_x.csv')
# Y_df = pd.read_csv('@datasets_reproducibity/Exchange/S/df_y.csv')

# %%
X_df
# Out:
#              ds  ex_1      ex_2      ex_3      ex_4
# 0    2002-01-01  -0.5 -0.333333 -0.500000 -0.500000
# 1    2002-01-08  -0.5 -0.333333 -0.266667 -0.480822
# 2    2002-01-15  -0.5 -0.333333 -0.033333 -0.461644
# 3    2002-01-22  -0.5 -0.333333  0.200000 -0.442466
# 4    2002-01-29  -0.5 -0.333333  0.433333 -0.423288
# ..          ...   ...       ...       ...       ...
# 961  2020-06-02  -0.5 -0.333333 -0.466667 -0.080822
# 962  2020-06-09  -0.5 -0.333333 -0.233333 -0.061644
# 963  2020-06-16  -0.5 -0.333333  0.000000 -0.042466
# 964  2020-06-23  -0.5 -0.333333  0.233333 -0.023288
# 965  2020-06-30  -0.5 -0.333333  0.466667 -0.004110
#
# [966 rows x 5 columns]

# %%
Y_df
# Out:
#               ds          unique_id         y
# 0     2002-01-01     % WEIGHTED ILI -0.421499
# 1     2002-01-01    %UNWEIGHTED ILI -0.472442
# 2     2002-01-01            AGE 0-4 -0.981641
# 3     2002-01-01           AGE 5-24 -0.692621
# 4     2002-01-01           ILITOTAL -0.819695
# ...          ...                ...       ...
# 6757  2020-06-30            AGE 0-4  0.602263
# 6758  2020-06-30           AGE 5-24  0.023051
# 6759  2020-06-30           ILITOTAL  0.651678
# 6760  2020-06-30  NUM. OF PROVIDERS  3.454565
# 6761  2020-06-30                 OT  4.441721
#
# [6762 rows x 3 columns]

# %%
a=Y_df['unique_id'].unique()
a.size
# Out:
# 7

# %%
merged_df = pd.merge(Y_df, X_df[['ds', 'ex_1', 'ex_2','ex_3','ex_4']], on='ds', how='left')
merged_df
# Out:
#               ds          unique_id         y  ex_1      ex_2      ex_3  \
# 0     2002-01-01     % WEIGHTED ILI -0.421499  -0.5 -0.333333 -0.500000
# 1     2002-01-01    %UNWEIGHTED ILI -0.472442  -0.5 -0.333333 -0.500000
# 2     2002-01-01            AGE 0-4 -0.981641  -0.5 -0.333333 -0.500000
# 3     2002-01-01           AGE 5-24 -0.692621  -0.5 -0.333333 -0.500000
# 4     2002-01-01           ILITOTAL -0.819695  -0.5 -0.333333 -0.500000
# ...          ...                ...       ...   ...       ...       ...
# 6757  2020-06-30            AGE 0-4  0.602263  -0.5 -0.333333  0.466667
# 6758  2020-06-30           AGE 5-24  0.023051  -0.5 -0.333333  0.466667
# 6759  2020-06-30           ILITOTAL  0.651678  -0.5 -0.333333  0.466667
# 6760  2020-06-30  NUM. OF PROVIDERS  3.454565  -0.5 -0.333333  0.466667
# 6761  2020-06-30                 OT  4.441721  -0.5 -0.333333  0.466667
#
#          ex_4
# 0    -0.50000
# 1    -0.50000
# 2    -0.50000
# 3    -0.50000
# 4    -0.50000
# ...       ...
# 6757 -0.00411
# 6758 -0.00411
# 6759 -0.00411
# 6760 -0.00411
# 6761 -0.00411
#
# [6762 rows x 7 columns]

# %%
filtered_df = merged_df[merged_df['unique_id'] == 'OT']
filtered_df.reset_index(drop=True, inplace=True)
filtered_df.drop("ds",axis=1,inplace=True)
filtered_df['ds'] = range(len(filtered_df))
Y_df=filtered_df
Y_df
# Out:
# <ipython-input-15-ca2bf7442fa3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop("ds",axis=1,inplace=True)
# <ipython-input-15-ca2bf7442fa3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['ds'] = range(len(filtered_df))
#     unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0          OT -1.385709  -0.5 -0.333333 -0.500000 -0.500000    0
# 1          OT -1.342939  -0.5 -0.333333 -0.266667 -0.480822    1
# 2          OT -1.316218  -0.5 -0.333333 -0.033333 -0.461644    2
# 3          OT -1.250473  -0.5 -0.333333  0.200000 -0.442466    3
# 4          OT -1.181873  -0.5 -0.333333  0.433333 -0.423288    4
# ..        ...       ...   ...       ...       ...       ...  ...
# 961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965
#
# [966 rows x 7 columns]

# %% [markdown]
# ## Horizon 24

# %%
Y_df=filtered_df

# %%
Y_train_df = Y_df.iloc[:942,:]
Y_test_df = Y_df.iloc[942:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#     index unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0     942        OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 1     943        OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 2     944        OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 3     945        OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 4     946        OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 5     947        OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 6     948        OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 7     949        OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 8     950        OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 9     951        OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 10    952        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 11    953        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 12    954        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 13    955        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 14    956        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 15    957        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 16    958        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 17    959        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 18    960        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 19    961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 20    962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 21    963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 22    964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 23    965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#    unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0         OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 1         OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 2         OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 3         OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 4         OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 5         OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 6         OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 7         OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 8         OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 9         OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 10        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 11        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 12        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 13        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 14        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 15        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 16        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 17        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 18        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 19        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 20        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 21        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 22        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 23        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
horizon = 24
model = NBEATS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq=1)

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 2.5 M
# -----------------------------------------------
# 2.5 M     Trainable params
# 2.4 K     Non-trainable params
# 2.5 M     Total params
# 9.918     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#            ds    NBEATS
# unique_id
# OT          0  4.415989
# OT          1  4.255467
# OT          2  3.817771
# OT          3  4.164146
# OT          4  4.146292
# OT          5  4.089744
# OT          6  3.835637
# OT          7  3.739863
# OT          8  3.630534
# OT          9  3.612355
# OT         10  3.613501
# OT         11  3.553557
# OT         12  3.066413
# OT         13  3.240780
# OT         14  3.434757
# OT         15  3.210975
# OT         16  2.946147
# OT         17  2.989370
# OT         18  3.215608
# OT         19  3.493833
# OT         20  3.440540
# OT         21  3.351631
# OT         22  3.263309
# OT         23  3.383771

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[['NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#       NBEATS
# ds
# 0   4.415989
# 1   4.255467
# 2   3.817771
# 3   4.164146
# 4   4.146292
# 5   4.089744
# 6   3.835637
# 7   3.739863
# 8   3.630534
# 9   3.612355
# 10  3.613501
# 11  3.553557
# 12  3.066413
# 13  3.240780
# 14  3.434757
# 15  3.210975
# 16  2.946147
# 17  2.989370
# 18  3.215608
# 19  3.493833
# 20  3.440540
# 21  3.351631
# 22  3.263309
# 23  3.383771

# %%
mae_nbeats = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_nbeats = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'NBEATS MAE: {mae_nbeats:.3f}')
print(f'NBEATS MSE: {mse_nbeats:.3f}')
# Out:
# NBEATS MAE: 0.893
# NBEATS MSE: 0.930

# %% [markdown]
# ## Horizon 36

# %%
Y_df
# Out:
#     unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0          OT -1.385709  -0.5 -0.333333 -0.500000 -0.500000    0
# 1          OT -1.342939  -0.5 -0.333333 -0.266667 -0.480822    1
# 2          OT -1.316218  -0.5 -0.333333 -0.033333 -0.461644    2
# 3          OT -1.250473  -0.5 -0.333333  0.200000 -0.442466    3
# 4          OT -1.181873  -0.5 -0.333333  0.433333 -0.423288    4
# ..        ...       ...   ...       ...       ...       ...  ...
# 961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965
#
# [966 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:930,:]
Y_test_df = Y_df.iloc[930:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#     index unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0     930        OT  3.728859  -0.5 -0.333333  0.433333  0.324658  930
# 1     931        OT  3.669735  -0.5 -0.333333 -0.366667  0.343836  931
# 2     932        OT  3.693310  -0.5 -0.333333 -0.133333  0.363014  932
# 3     933        OT  3.716836  -0.5 -0.333333  0.100000  0.382192  933
# 4     934        OT  3.747381  -0.5 -0.333333  0.333333  0.401370  934
# 5     935        OT  3.683140  -0.5 -0.333333 -0.433333  0.420548  935
# 6     936        OT  3.641755  -0.5 -0.333333 -0.200000  0.439726  936
# 7     937        OT  3.783136  -0.5 -0.333333  0.033333  0.458904  937
# 8     938        OT  3.948533  -0.5 -0.333333  0.266667  0.478082  938
# 9     939        OT  4.571083  -0.5 -0.333333  0.500000  0.497260  939
# 10    940        OT  4.902510  -0.5 -0.333333 -0.300000 -0.483562  940
# 11    941        OT  4.757301  -0.5 -0.333333 -0.066667 -0.464384  941
# 12    942        OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 13    943        OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 14    944        OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 15    945        OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 16    946        OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 17    947        OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 18    948        OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 19    949        OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 20    950        OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 21    951        OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 22    952        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 23    953        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 24    954        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 25    955        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 26    956        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 27    957        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 28    958        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 29    959        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 30    960        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 31    961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 32    962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 33    963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 34    964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 35    965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#    unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0         OT  3.728859  -0.5 -0.333333  0.433333  0.324658  930
# 1         OT  3.669735  -0.5 -0.333333 -0.366667  0.343836  931
# 2         OT  3.693310  -0.5 -0.333333 -0.133333  0.363014  932
# 3         OT  3.716836  -0.5 -0.333333  0.100000  0.382192  933
# 4         OT  3.747381  -0.5 -0.333333  0.333333  0.401370  934
# 5         OT  3.683140  -0.5 -0.333333 -0.433333  0.420548  935
# 6         OT  3.641755  -0.5 -0.333333 -0.200000  0.439726  936
# 7         OT  3.783136  -0.5 -0.333333  0.033333  0.458904  937
# 8         OT  3.948533  -0.5 -0.333333  0.266667  0.478082  938
# 9         OT  4.571083  -0.5 -0.333333  0.500000  0.497260  939
# 10        OT  4.902510  -0.5 -0.333333 -0.300000 -0.483562  940
# 11        OT  4.757301  -0.5 -0.333333 -0.066667 -0.464384  941
# 12        OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 13        OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 14        OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 15        OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 16        OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 17        OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 18        OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 19        OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 20        OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 21        OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 22        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 23        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 24        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 25        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 26        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 27        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 28        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 29        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 30        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 31        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 32        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 33        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 34        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 35        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
horizon = 36
model = NBEATS(h=horizon, input_size=24,
               max_steps=2000,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq=1)

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 2.5 M
# -----------------------------------------------
# 2.5 M     Trainable params
# 4.4 K     Non-trainable params
# 2.5 M     Total params
# 10.049    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=2000` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#            ds    NBEATS
# unique_id
# OT          0  3.747409
# OT          1  4.726486
# OT          2  4.163231
# OT          3  3.177892
# OT          4  4.644654
# OT          5  4.323500
# OT          6  4.411377
# OT          7  5.072486
# OT          8  4.963837
# OT          9  5.534894
# OT         10  6.222031
# OT         11  5.530124
# OT         12  5.071824
# OT         13  5.210580
# OT         14  4.398536
# OT         15  5.459109
# OT         16  4.208415
# OT         17  3.960962
# OT         18  4.782854
# OT         19  3.026534
# OT         20  3.962807
# OT         21  2.393621
# OT         22  2.356220
# OT         23  2.279388
# OT         24  3.067982
# OT         25  2.198455
# OT         26  2.631635
# OT         27  3.921635
# OT         28  2.979628
# OT         29  2.779735
# OT         30  2.901393
# OT         31  3.527438
# OT         32  3.285750
# OT         33  2.884719
# OT         34  4.263720
# OT         35  3.365387

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#       NBEATS
# ds
# 0   3.747409
# 1   4.726486
# 2   4.163231
# 3   3.177892
# 4   4.644654
# 5   4.323500
# 6   4.411377
# 7   5.072486
# 8   4.963837
# 9   5.534894
# 10  6.222031
# 11  5.530124
# 12  5.071824
# 13  5.210580
# 14  4.398536
# 15  5.459109
# 16  4.208415
# 17  3.960962
# 18  4.782854
# 19  3.026534
# 20  3.962807
# 21  2.393621
# 22  2.356220
# 23  2.279388
# 24  3.067982
# 25  2.198455
# 26  2.631635
# 27  3.921635
# 28  2.979628
# 29  2.779735
# 30  2.901393
# 31  3.527438
# 32  3.285750
# 33  2.884719
# 34  4.263720
# 35  3.365387

# %%
mae_nbeats = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_nbeats = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'NBEATS MAE: {mae_nbeats:.3f}')
print(f'NBEATS MSE: {mse_nbeats:.3f}')
# Out:
# NBEATS MAE: 0.977
# NBEATS MSE: 1.308

# %% [markdown]
# ## Horizon 48

# %%
Y_df
# Out:
#     unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0          OT -1.385709  -0.5 -0.333333 -0.500000 -0.500000    0
# 1          OT -1.342939  -0.5 -0.333333 -0.266667 -0.480822    1
# 2          OT -1.316218  -0.5 -0.333333 -0.033333 -0.461644    2
# 3          OT -1.250473  -0.5 -0.333333  0.200000 -0.442466    3
# 4          OT -1.181873  -0.5 -0.333333  0.433333 -0.423288    4
# ..        ...       ...   ...       ...       ...       ...  ...
# 961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965
#
# [966 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:918,:]
Y_test_df = Y_df.iloc[918:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#     index unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0     918        OT  1.416744  -0.5 -0.333333 -0.333333  0.094521  918
# 1     919        OT  1.542186  -0.5 -0.333333 -0.100000  0.113699  919
# 2     920        OT  2.474883  -0.5 -0.333333  0.133333  0.132877  920
# 3     921        OT  2.571790  -0.5 -0.333333  0.366667  0.152055  921
# 4     922        OT  2.803050  -0.5 -0.333333 -0.433333  0.171233  922
# 5     923        OT  2.975925  -0.5 -0.333333 -0.200000  0.190411  923
# 6     924        OT  3.293017  -0.5 -0.333333  0.033333  0.209589  924
# 7     925        OT  3.468571  -0.5 -0.333333  0.266667  0.228767  925
# 8     926        OT  3.469169  -0.5 -0.333333 -0.500000  0.247945  926
# 9     927        OT  3.786624  -0.5 -0.333333 -0.266667  0.267123  927
# 10    928        OT  3.692991  -0.5 -0.333333 -0.033333  0.286301  928
# 11    929        OT  3.765440  -0.5 -0.333333  0.200000  0.305479  929
# 12    930        OT  3.728859  -0.5 -0.333333  0.433333  0.324658  930
# 13    931        OT  3.669735  -0.5 -0.333333 -0.366667  0.343836  931
# 14    932        OT  3.693310  -0.5 -0.333333 -0.133333  0.363014  932
# 15    933        OT  3.716836  -0.5 -0.333333  0.100000  0.382192  933
# 16    934        OT  3.747381  -0.5 -0.333333  0.333333  0.401370  934
# 17    935        OT  3.683140  -0.5 -0.333333 -0.433333  0.420548  935
# 18    936        OT  3.641755  -0.5 -0.333333 -0.200000  0.439726  936
# 19    937        OT  3.783136  -0.5 -0.333333  0.033333  0.458904  937
# 20    938        OT  3.948533  -0.5 -0.333333  0.266667  0.478082  938
# 21    939        OT  4.571083  -0.5 -0.333333  0.500000  0.497260  939
# 22    940        OT  4.902510  -0.5 -0.333333 -0.300000 -0.483562  940
# 23    941        OT  4.757301  -0.5 -0.333333 -0.066667 -0.464384  941
# 24    942        OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 25    943        OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 26    944        OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 27    945        OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 28    946        OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 29    947        OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 30    948        OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 31    949        OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 32    950        OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 33    951        OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 34    952        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 35    953        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 36    954        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 37    955        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 38    956        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 39    957        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 40    958        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 41    959        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 42    960        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 43    961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 44    962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 45    963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 46    964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 47    965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#    unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0         OT  1.416744  -0.5 -0.333333 -0.333333  0.094521  918
# 1         OT  1.542186  -0.5 -0.333333 -0.100000  0.113699  919
# 2         OT  2.474883  -0.5 -0.333333  0.133333  0.132877  920
# 3         OT  2.571790  -0.5 -0.333333  0.366667  0.152055  921
# 4         OT  2.803050  -0.5 -0.333333 -0.433333  0.171233  922
# 5         OT  2.975925  -0.5 -0.333333 -0.200000  0.190411  923
# 6         OT  3.293017  -0.5 -0.333333  0.033333  0.209589  924
# 7         OT  3.468571  -0.5 -0.333333  0.266667  0.228767  925
# 8         OT  3.469169  -0.5 -0.333333 -0.500000  0.247945  926
# 9         OT  3.786624  -0.5 -0.333333 -0.266667  0.267123  927
# 10        OT  3.692991  -0.5 -0.333333 -0.033333  0.286301  928
# 11        OT  3.765440  -0.5 -0.333333  0.200000  0.305479  929
# 12        OT  3.728859  -0.5 -0.333333  0.433333  0.324658  930
# 13        OT  3.669735  -0.5 -0.333333 -0.366667  0.343836  931
# 14        OT  3.693310  -0.5 -0.333333 -0.133333  0.363014  932
# 15        OT  3.716836  -0.5 -0.333333  0.100000  0.382192  933
# 16        OT  3.747381  -0.5 -0.333333  0.333333  0.401370  934
# 17        OT  3.683140  -0.5 -0.333333 -0.433333  0.420548  935
# 18        OT  3.641755  -0.5 -0.333333 -0.200000  0.439726  936
# 19        OT  3.783136  -0.5 -0.333333  0.033333  0.458904  937
# 20        OT  3.948533  -0.5 -0.333333  0.266667  0.478082  938
# 21        OT  4.571083  -0.5 -0.333333  0.500000  0.497260  939
# 22        OT  4.902510  -0.5 -0.333333 -0.300000 -0.483562  940
# 23        OT  4.757301  -0.5 -0.333333 -0.066667 -0.464384  941
# 24        OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 25        OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 26        OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 27        OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 28        OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 29        OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 30        OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 31        OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 32        OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 33        OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 34        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 35        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 36        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 37        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 38        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 39        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 40        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 41        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 42        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 43        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 44        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 45        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 46        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 47        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
horizon = 48
model = NBEATS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq=1)

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 2.5 M
# -----------------------------------------------
# 2.5 M     Trainable params
# 7.0 K     Non-trainable params
# 2.5 M     Total params
# 10.183    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#            ds    NBEATS
# unique_id
# OT          0  1.715187
# OT          1  1.715075
# OT          2  1.638759
# OT          3  1.214774
# OT          4  1.379706
# OT          5  1.832674
# OT          6  1.939997
# OT          7  1.568790
# OT          8  1.985613
# OT          9  1.650390
# OT         10  2.032722
# OT         11  4.053985
# OT         12  3.446026
# OT         13  4.277925
# OT         14  5.297438
# OT         15  4.707276
# OT         16  5.259489
# OT         17  4.488670
# OT         18  5.234629
# OT         19  4.740863
# OT         20  5.346680
# OT         21  4.508997
# OT         22  5.760100
# OT         23  4.658980
# OT         24  5.209565
# OT         25  3.567960
# OT         26  4.250272
# OT         27  5.787498
# OT         28  6.674846
# OT         29  6.095157
# OT         30  6.001326
# OT         31  6.644053
# OT         32  6.498996
# OT         33  6.095751
# OT         34  6.709038
# OT         35  5.869163
# OT         36  4.926092
# OT         37  3.430881
# OT         38  3.814941
# OT         39  3.807567
# OT         40  3.498366
# OT         41  3.584604
# OT         42  3.405950
# OT         43  4.151475
# OT         44  3.675528
# OT         45  3.390120
# OT         46  3.833818
# OT         47  3.885443

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#       NBEATS
# ds
# 0   1.715187
# 1   1.715075
# 2   1.638759
# 3   1.214774
# 4   1.379706
# 5   1.832674
# 6   1.939997
# 7   1.568790
# 8   1.985613
# 9   1.650390
# 10  2.032722
# 11  4.053985
# 12  3.446026
# 13  4.277925
# 14  5.297438
# 15  4.707276
# 16  5.259489
# 17  4.488670
# 18  5.234629
# 19  4.740863
# 20  5.346680
# 21  4.508997
# 22  5.760100
# 23  4.658980
# 24  5.209565
# 25  3.567960
# 26  4.250272
# 27  5.787498
# 28  6.674846
# 29  6.095157
# 30  6.001326
# 31  6.644053
# 32  6.498996
# 33  6.095751
# 34  6.709038
# 35  5.869163
# 36  4.926092
# 37  3.430881
# 38  3.814941
# 39  3.807567
# 40  3.498366
# 41  3.584604
# 42  3.405950
# 43  4.151475
# 44  3.675528
# 45  3.390120
# 46  3.833818
# 47  3.885443

# %%
mae_nbeats = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_nbeats = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'NBEATS MAE: {mae_nbeats:.3f}')
print(f'NBEATS MSE: {mse_nbeats:.3f}')
# Out:
# NBEATS MAE: 1.074
# NBEATS MSE: 1.552

# %% [markdown]
# ## Horizon 60

# %%
Y_df
# Out:
#     unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0          OT -1.385709  -0.5 -0.333333 -0.500000 -0.500000    0
# 1          OT -1.342939  -0.5 -0.333333 -0.266667 -0.480822    1
# 2          OT -1.316218  -0.5 -0.333333 -0.033333 -0.461644    2
# 3          OT -1.250473  -0.5 -0.333333  0.200000 -0.442466    3
# 4          OT -1.181873  -0.5 -0.333333  0.433333 -0.423288    4
# ..        ...       ...   ...       ...       ...       ...  ...
# 961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965
#
# [966 rows x 7 columns]

# %%
Y_train_df = Y_df.iloc[:908,:]
Y_test_df = Y_df.iloc[908:,:]

# %%
Y_test_df = Y_test_df.reset_index()

# %%
Y_test_df
# Out:
#     index unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0     908        OT  4.251246  -0.5 -0.333333  0.400000 -0.097260  908
# 1     909        OT  4.352047  -0.5 -0.333333 -0.400000 -0.078082  909
# 2     910        OT  4.071296  -0.5 -0.333333 -0.166667 -0.058904  910
# 3     911        OT  2.513580  -0.5 -0.333333  0.066667 -0.039726  911
# 4     912        OT  1.572509  -0.5 -0.333333  0.300000 -0.020548  912
# 5     913        OT  1.122851  -0.5 -0.333333 -0.466667 -0.001370  913
# 6     914        OT  0.984774  -0.5 -0.333333 -0.233333  0.017808  914
# 7     915        OT  0.945514  -0.5 -0.333333  0.000000  0.036986  915
# 8     916        OT  1.122982  -0.5 -0.333333  0.233333  0.056164  916
# 9     917        OT  1.299143  -0.5 -0.333333  0.466667  0.075342  917
# 10    918        OT  1.416744  -0.5 -0.333333 -0.333333  0.094521  918
# 11    919        OT  1.542186  -0.5 -0.333333 -0.100000  0.113699  919
# 12    920        OT  2.474883  -0.5 -0.333333  0.133333  0.132877  920
# 13    921        OT  2.571790  -0.5 -0.333333  0.366667  0.152055  921
# 14    922        OT  2.803050  -0.5 -0.333333 -0.433333  0.171233  922
# 15    923        OT  2.975925  -0.5 -0.333333 -0.200000  0.190411  923
# 16    924        OT  3.293017  -0.5 -0.333333  0.033333  0.209589  924
# 17    925        OT  3.468571  -0.5 -0.333333  0.266667  0.228767  925
# 18    926        OT  3.469169  -0.5 -0.333333 -0.500000  0.247945  926
# 19    927        OT  3.786624  -0.5 -0.333333 -0.266667  0.267123  927
# 20    928        OT  3.692991  -0.5 -0.333333 -0.033333  0.286301  928
# 21    929        OT  3.765440  -0.5 -0.333333  0.200000  0.305479  929
# 22    930        OT  3.728859  -0.5 -0.333333  0.433333  0.324658  930
# 23    931        OT  3.669735  -0.5 -0.333333 -0.366667  0.343836  931
# 24    932        OT  3.693310  -0.5 -0.333333 -0.133333  0.363014  932
# 25    933        OT  3.716836  -0.5 -0.333333  0.100000  0.382192  933
# 26    934        OT  3.747381  -0.5 -0.333333  0.333333  0.401370  934
# 27    935        OT  3.683140  -0.5 -0.333333 -0.433333  0.420548  935
# 28    936        OT  3.641755  -0.5 -0.333333 -0.200000  0.439726  936
# 29    937        OT  3.783136  -0.5 -0.333333  0.033333  0.458904  937
# 30    938        OT  3.948533  -0.5 -0.333333  0.266667  0.478082  938
# 31    939        OT  4.571083  -0.5 -0.333333  0.500000  0.497260  939
# 32    940        OT  4.902510  -0.5 -0.333333 -0.300000 -0.483562  940
# 33    941        OT  4.757301  -0.5 -0.333333 -0.066667 -0.464384  941
# 34    942        OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 35    943        OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 36    944        OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 37    945        OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 38    946        OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 39    947        OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 40    948        OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 41    949        OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 42    950        OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 43    951        OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 44    952        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 45    953        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 46    954        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 47    955        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 48    956        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 49    957        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 50    958        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 51    959        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 52    960        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 53    961        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 54    962        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 55    963        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 56    964        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 57    965        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
Y_test_df.drop(['index'], axis=1, inplace=True)
Y_test_df
# Out:
#    unique_id         y  ex_1      ex_2      ex_3      ex_4   ds
# 0         OT  4.251246  -0.5 -0.333333  0.400000 -0.097260  908
# 1         OT  4.352047  -0.5 -0.333333 -0.400000 -0.078082  909
# 2         OT  4.071296  -0.5 -0.333333 -0.166667 -0.058904  910
# 3         OT  2.513580  -0.5 -0.333333  0.066667 -0.039726  911
# 4         OT  1.572509  -0.5 -0.333333  0.300000 -0.020548  912
# 5         OT  1.122851  -0.5 -0.333333 -0.466667 -0.001370  913
# 6         OT  0.984774  -0.5 -0.333333 -0.233333  0.017808  914
# 7         OT  0.945514  -0.5 -0.333333  0.000000  0.036986  915
# 8         OT  1.122982  -0.5 -0.333333  0.233333  0.056164  916
# 9         OT  1.299143  -0.5 -0.333333  0.466667  0.075342  917
# 10        OT  1.416744  -0.5 -0.333333 -0.333333  0.094521  918
# 11        OT  1.542186  -0.5 -0.333333 -0.100000  0.113699  919
# 12        OT  2.474883  -0.5 -0.333333  0.133333  0.132877  920
# 13        OT  2.571790  -0.5 -0.333333  0.366667  0.152055  921
# 14        OT  2.803050  -0.5 -0.333333 -0.433333  0.171233  922
# 15        OT  2.975925  -0.5 -0.333333 -0.200000  0.190411  923
# 16        OT  3.293017  -0.5 -0.333333  0.033333  0.209589  924
# 17        OT  3.468571  -0.5 -0.333333  0.266667  0.228767  925
# 18        OT  3.469169  -0.5 -0.333333 -0.500000  0.247945  926
# 19        OT  3.786624  -0.5 -0.333333 -0.266667  0.267123  927
# 20        OT  3.692991  -0.5 -0.333333 -0.033333  0.286301  928
# 21        OT  3.765440  -0.5 -0.333333  0.200000  0.305479  929
# 22        OT  3.728859  -0.5 -0.333333  0.433333  0.324658  930
# 23        OT  3.669735  -0.5 -0.333333 -0.366667  0.343836  931
# 24        OT  3.693310  -0.5 -0.333333 -0.133333  0.363014  932
# 25        OT  3.716836  -0.5 -0.333333  0.100000  0.382192  933
# 26        OT  3.747381  -0.5 -0.333333  0.333333  0.401370  934
# 27        OT  3.683140  -0.5 -0.333333 -0.433333  0.420548  935
# 28        OT  3.641755  -0.5 -0.333333 -0.200000  0.439726  936
# 29        OT  3.783136  -0.5 -0.333333  0.033333  0.458904  937
# 30        OT  3.948533  -0.5 -0.333333  0.266667  0.478082  938
# 31        OT  4.571083  -0.5 -0.333333  0.500000  0.497260  939
# 32        OT  4.902510  -0.5 -0.333333 -0.300000 -0.483562  940
# 33        OT  4.757301  -0.5 -0.333333 -0.066667 -0.464384  941
# 34        OT  4.744937  -0.5 -0.333333  0.166667 -0.445205  942
# 35        OT  4.676394  -0.5 -0.333333  0.400000 -0.426027  943
# 36        OT  4.841205  -0.5 -0.333333 -0.400000 -0.406849  944
# 37        OT  5.012764  -0.5 -0.333333 -0.166667 -0.387671  945
# 38        OT  4.792059  -0.5 -0.333333  0.066667 -0.368493  946
# 39        OT  4.062765  -0.5 -0.333333  0.300000 -0.349315  947
# 40        OT  4.559790  -0.5 -0.333333 -0.433333 -0.330137  948
# 41        OT  4.628376  -0.5 -0.333333 -0.200000 -0.310959  949
# 42        OT  4.362484  -0.5 -0.333333  0.033333 -0.291781  950
# 43        OT  3.791576  -0.5 -0.333333  0.266667 -0.272603  951
# 44        OT  4.211060  -0.5 -0.333333  0.500000 -0.253425  952
# 45        OT  4.754329  -0.5 -0.333333 -0.300000 -0.234247  953
# 46        OT  4.473429  -0.5 -0.333333 -0.066667 -0.215068  954
# 47        OT  4.459351  -0.5 -0.333333  0.166667 -0.195890  955
# 48        OT  4.416079  -0.5 -0.333333  0.400000 -0.176712  956
# 49        OT  4.310685  -0.5 -0.333333 -0.366667 -0.157534  957
# 50        OT  4.128881  -0.5 -0.333333 -0.133333 -0.138356  958
# 51        OT  3.879908  -0.5 -0.333333  0.100000 -0.119178  959
# 52        OT  4.562818  -0.5 -0.333333  0.333333 -0.100000  960
# 53        OT  4.507846  -0.5 -0.333333 -0.466667 -0.080822  961
# 54        OT  4.564575  -0.5 -0.333333 -0.233333 -0.061644  962
# 55        OT  4.521154  -0.5 -0.333333  0.000000 -0.042466  963
# 56        OT  4.585444  -0.5 -0.333333  0.233333 -0.023288  964
# 57        OT  4.441721  -0.5 -0.333333  0.466667 -0.004110  965

# %%
horizon = 60
model = NBEATS(h=horizon, input_size=24,
               max_steps=1000,
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=[model],freq=1)

# %%
nf.fit(df=Y_train_df)
forecasts = nf.predict()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params
# -----------------------------------------------
# 0 | loss         | MAE           | 0
# 1 | padder_train | ConstantPad1d | 0
# 2 | scaler       | TemporalNorm  | 0
# 3 | blocks       | ModuleList    | 2.6 M
# -----------------------------------------------
# 2.6 M     Trainable params
# 10.2 K    Non-trainable params
# 2.6 M     Total params
# 10.319    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.
# /usr/local/lib/python3.10/dist-packages/neuralforecast/tsdataset.py:92: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.temporal = torch.tensor(temporal, dtype=torch.float)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/neuralforecast/core.py:184: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
forecasts['ds'] = [i for i in range(len(forecasts))]
forecasts
# Out:
#            ds    NBEATS
# unique_id
# OT          0  3.876605
# OT          1  4.320598
# OT          2  4.032587
# OT          3  4.011724
# OT          4  4.039855
# OT          5  4.221099
# OT          6  4.090529
# OT          7  3.903522
# OT          8  3.862438
# OT          9  4.153787
# OT         10  3.891316
# OT         11  3.611253
# OT         12  3.479798
# OT         13  3.457261
# OT         14  3.610511
# OT         15  3.591539
# OT         16  3.587658
# OT         17  3.686025
# OT         18  3.519745
# OT         19  3.653400
# OT         20  3.665572
# OT         21  3.515214
# OT         22  3.466647
# OT         23  3.641147
# OT         24  3.786652
# OT         25  3.859566
# OT         26  3.909380
# OT         27  3.627234
# OT         28  4.093230
# OT         29  4.505582
# OT         30  4.617388
# OT         31  5.450091
# OT         32  5.417145
# OT         33  5.582736
# OT         34  5.436899
# OT         35  5.401688
# OT         36  5.397505
# OT         37  5.590778
# OT         38  5.467082
# OT         39  5.093177
# OT         40  5.510839
# OT         41  5.347143
# OT         42  5.419527
# OT         43  5.064751
# OT         44  5.100141
# OT         45  5.218698
# OT         46  5.241061
# OT         47  5.704311
# OT         48  5.679144
# OT         49  5.787192
# OT         50  5.509045
# OT         51  5.388381
# OT         52  5.727629
# OT         53  6.030210
# OT         54  6.168226
# OT         55  5.803046
# OT         56  5.582082
# OT         57  5.558547
# OT         58  5.393187
# OT         59  5.445546

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 7))
plot_df = forecasts.set_index('ds')
Y_test_df[['y']].plot(ax=ax,linewidth=2)
plot_df[[ 'NBEATS']].plot(ax=ax, linewidth=2)
# Out:
# <Axes: xlabel='ds'>

# %%
forecasts=forecasts.set_index('ds')
forecasts
# Out:
#       NBEATS
# ds
# 0   3.876605
# 1   4.320598
# 2   4.032587
# 3   4.011724
# 4   4.039855
# 5   4.221099
# 6   4.090529
# 7   3.903522
# 8   3.862438
# 9   4.153787
# 10  3.891316
# 11  3.611253
# 12  3.479798
# 13  3.457261
# 14  3.610511
# 15  3.591539
# 16  3.587658
# 17  3.686025
# 18  3.519745
# 19  3.653400
# 20  3.665572
# 21  3.515214
# 22  3.466647
# 23  3.641147
# 24  3.786652
# 25  3.859566
# 26  3.909380
# 27  3.627234
# 28  4.093230
# 29  4.505582
# 30  4.617388
# 31  5.450091
# 32  5.417145
# 33  5.582736
# 34  5.436899
# 35  5.401688
# 36  5.397505
# 37  5.590778
# 38  5.467082
# 39  5.093177
# 40  5.510839
# 41  5.347143
# 42  5.419527
# 43  5.064751
# 44  5.100141
# 45  5.218698
# 46  5.241061
# 47  5.704311
# 48  5.679144
# 49  5.787192
# 50  5.509045
# 51  5.388381
# 52  5.727629
# 53  6.030210
# 54  6.168226
# 55  5.803046
# 56  5.582082
# 57  5.558547
# 58  5.393187
# 59  5.445546

# %%
mae_nbeats = mae(Y_test_df['y'], forecasts['NBEATS'])
mse_nbeats = mse(Y_test_df['y'], forecasts['NBEATS'])
print(f'NBEATS MAE: {mae_nbeats:.3f}')
print(f'NBEATS MSE: {mse_nbeats:.3f}')
# Out:
# NBEATS MAE: 0.996
# NBEATS MSE: 1.675
